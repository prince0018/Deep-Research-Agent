# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

api_key = os.getenv("OPENAI_API_KEY")   # replace with your variable name
if api_key:
    print("API KEY FOUND!")
# Out:
# oh yes... Here I am
